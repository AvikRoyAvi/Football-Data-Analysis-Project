# %%
#Import the libraries
import numpy as np
import pandas as pd
from matplotlib import pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
#Load dataset
df = pd.read_csv('D:\Python codes\Football Data Analysis Project using python\EPL_20_21.csv')
df
# Out:
#                   Name              Club Nationality Position  Age  Matches  \
# 0          Mason Mount           Chelsea         ENG    MF,FW   21       36
# 1        Edouard Mendy           Chelsea         SEN       GK   28       31
# 2          Timo Werner           Chelsea         GER       FW   24       35
# 3         Ben Chilwell           Chelsea         ENG       DF   23       27
# 4          Reece James           Chelsea         ENG       DF   20       32
# ..                 ...               ...         ...      ...  ...      ...
# 527        Lys Mousset  Sheffield United         FRA    FW,MF   24       11
# 528     Jack O'Connell  Sheffield United         ENG       DF   26        2
# 529      Iliman Ndiaye  Sheffield United         FRA       MF   21        1
# 530  Antwoine Hackford  Sheffield United         ENG    DF,FW   16        1
# 531        Femi Seriki  Sheffield United         ENG       DF   17        1
#
# ...

# %%
df.info
# Out:
# <bound method DataFrame.info of                   Name              Club Nationality Position  Age  Matches  \
# 0          Mason Mount           Chelsea         ENG    MF,FW   21       36
# 1        Edouard Mendy           Chelsea         SEN       GK   28       31
# 2          Timo Werner           Chelsea         GER       FW   24       35
# 3         Ben Chilwell           Chelsea         ENG       DF   23       27
# 4          Reece James           Chelsea         ENG       DF   20       32
# ..                 ...               ...         ...      ...  ...      ...
# 527        Lys Mousset  Sheffield United         FRA    FW,MF   24       11
# 528     Jack O'Connell  Sheffield United         ENG       DF   26        2
# 529      Iliman Ndiaye  Sheffield United         FRA       MF   21        1
# 530  Antwoine Hackford  Sheffield United         ENG    DF,FW   16        1
# 531        Femi Seriki  Sheffield United         ENG       DF   17        1
#
# ...

# %%
df.describe()
# Out:
#               Age     Matches      Starts         Mins       Goals  \
# count  532.000000  532.000000  532.000000   532.000000  532.000000
# mean    25.500000   19.535714   15.714286  1411.443609    1.853383
# std      4.319404   11.840459   11.921161  1043.171856    3.338009
# min     16.000000    1.000000    0.000000     1.000000    0.000000
# 25%     22.000000    9.000000    4.000000   426.000000    0.000000
# 50%     26.000000   21.000000   15.000000  1345.000000    1.000000
# 75%     29.000000   30.000000   27.000000  2303.500000    2.000000
# max     38.000000   38.000000   38.000000  3420.000000   23.000000
#
#           Assists  Passes_Attempted  Perc_Passes_Completed  Penalty_Goals  \
# count  532.000000        532.000000             532.000000     532.000000
# mean     1.287594        717.750000              77.823872       0.191729
# std      2.095191        631.372522              13.011631       0.850881
# ...

# %%
df.isna().sum()
# Out:
# Name                     0
# Club                     0
# Nationality              0
# Position                 0
# Age                      0
# Matches                  0
# Starts                   0
# Mins                     0
# Goals                    0
# Assists                  0
# Passes_Attempted         0
# Perc_Passes_Completed    0
# Penalty_Goals            0
# Penalty_Attempted        0
# xG                       0
# xA                       0
# Yellow_Cards             0
# Red_Cards                0
# dtype: int64

# %%
#Create 2 more columns
df['MinsPerMatch'] = (df['Mins'] / df['Matches']).astype(int)
df['GoalsPerMatch'] = (df['Goals'] / df['Matches']).astype(float)
df.head()
# Out:
#             Name     Club Nationality Position  Age  Matches  Starts  Mins  \
# 0    Mason Mount  Chelsea         ENG    MF,FW   21       36      32  2890
# 1  Edouard Mendy  Chelsea         SEN       GK   28       31      31  2745
# 2    Timo Werner  Chelsea         GER       FW   24       35      29  2602
# 3   Ben Chilwell  Chelsea         ENG       DF   23       27      27  2286
# 4    Reece James  Chelsea         ENG       DF   20       32      25  2373
#
#    Goals  Assists  Passes_Attempted  Perc_Passes_Completed  Penalty_Goals  \
# 0      6        5              1881                   82.3              1
# 1      0        0              1007                   84.6              0
# 2      6        8               826                   77.2              0
# 3      3        5              1806                   78.6              0
# 4      1        2              1987                   85.0              0
#
# ...

# %%
df
# Out:
#                   Name              Club Nationality Position  Age  Matches  \
# 0          Mason Mount           Chelsea         ENG    MF,FW   21       36
# 1        Edouard Mendy           Chelsea         SEN       GK   28       31
# 2          Timo Werner           Chelsea         GER       FW   24       35
# 3         Ben Chilwell           Chelsea         ENG       DF   23       27
# 4          Reece James           Chelsea         ENG       DF   20       32
# ..                 ...               ...         ...      ...  ...      ...
# 527        Lys Mousset  Sheffield United         FRA    FW,MF   24       11
# 528     Jack O'Connell  Sheffield United         ENG       DF   26        2
# 529      Iliman Ndiaye  Sheffield United         FRA       MF   21        1
# 530  Antwoine Hackford  Sheffield United         ENG    DF,FW   16        1
# 531        Femi Seriki  Sheffield United         ENG       DF   17        1
#
# ...

# %%
#Total Goals
total_goals = df['Goals'].sum()
print(total_goals)
# Out:
# 986

# %%
#Penalty Goals
penalty_goals = df['Penalty_Goals'].sum()
print(penalty_goals)
# Out:
# 102

# %%
#Penalty Attempted
penalty_attempted = df['Penalty_Attempted'].sum()
print(penalty_attempted)
# Out:
# 125

# %%
#Pie chart for penalties missed VS scored
plt.figure(figsize = (12, 6))
not_scored = df['Penalty_Attempted'].sum() - penalty_goals
data = [not_scored, penalty_goals]
labels = ['Penalties missed', 'Penalties scored']
colors = ['r', 'g']
textprops = {"fontsize": 15}
plt.pie(data, labels = labels, colors = colors, autopct = '%0.1f%%', shadow = True, radius = 2, textprops = textprops)
plt.legend()
plt.show()

# %%
#Unique position
df['Position'].unique()
# Out:
# array(['MF,FW', 'GK', 'FW', 'DF', 'MF', 'FW,MF', 'FW,DF', 'DF,MF',
#        'MF,DF', 'DF,FW'], dtype=object)

# %%
#Total FW players
df[df['Position'] == 'FW']
# Out:
#                    Name              Club Nationality Position  Age  Matches  \
# 2           Timo Werner           Chelsea         GER       FW   24       35
# 16        Tammy Abraham           Chelsea         ENG       FW   22       22
# 19       Olivier Giroud           Chelsea         FRA       FW   33       17
# 23   Ruben Loftus-Cheek           Chelsea         ENG       FW   24        1
# 30      Raheem Sterling   Manchester City         ENG       FW   25       31
# ..                  ...               ...         ...      ...  ...      ...
# 516        Oliver Burke  Sheffield United         SCO       FW   23       25
# 518     Oliver McBurnie  Sheffield United         SCO       FW   24       23
# 519      Rhian Brewster  Sheffield United         ENG       FW   20       27
# 523         Billy Sharp  Sheffield United         ENG       FW   34       16
# 526     Daniel Jebbison  Sheffield United         ENG       FW   17        4
#
# ...

# %%
#Player from different nation
np.size(df['Nationality'].unique())
# Out:
# 59

# %%
#Most players from which country
nationality = df.groupby('Nationality').size().sort_values(ascending = False)
nationality.head(10).plot(kind = 'bar', figsize = (12, 6), color = sns.color_palette('hot'))
plt.show()

# %%
#Club of maximum players in their squad
df['Club'].value_counts().nlargest(5).plot(kind = 'bar', color = sns.color_palette('rainbow'), figsize = (12, 6))
plt.show()

# %%
#Club of least players in their squad
df['Club'].value_counts().nsmallest(5).plot(kind = 'bar', color = sns.color_palette('twilight'), figsize = (12, 6))
plt.show()

# %%
#Players based on age group
under_20 = df[df['Age'] <= 20]
age_20_25 = df[(df['Age'] > 20) & (df['Age'] <= 25)]
age_25_30 = df[(df['Age'] > 25) & (df['Age'] <= 30)]
above_30 = df[df['Age'] > 30]

# %%
x = np.array([under_20['Name'].count(), age_20_25['Name'].count(), age_25_30['Name'].count(), above_30['Name'].count()])
plt.figure(figsize = (12, 6))
labels = ['<=20', '>20&<=25', '>25&<=30', '>30']
textprops = {"fontsize": 12}
plt.title('Total players with age', fontsize = 20)
plt.pie(x, labels = labels, autopct = '%.1f%%', textprops = textprops)
plt.show()

# %%
#Total under 20 players in each club
plt.figure(figsize = (16, 9))
players_under_20 = df[df['Age'] < 20]
players_under_20['Club'].value_counts().plot(kind = 'bar', color = sns.color_palette('ocean'))
plt.show()

# %%
#Under 20 players in manU
players_under_20[players_under_20['Club'] == 'Manchester City']
# Out:
#            Name             Club Nationality Position  Age  Matches  Starts  \
# 47  Eric García  Manchester City         ESP       DF   19        6       3
# 50   Liam Delap  Manchester City         ENG       FW   17        1       0
#
#     Mins  Goals  Assists  Passes_Attempted  Perc_Passes_Completed  \
# 47   383      0        0               344                   93.6
# 50    40      0        0                 7                   71.4
#
#     Penalty_Goals  Penalty_Attempted    xG    xA  Yellow_Cards  Red_Cards  \
# 47              0                  0  0.03  0.02             0          0
# 50              0                  0  0.06  0.00             0          0
#
#     MinsPerMatch  GoalsPerMatch
# 47            63            0.0
# 50            40            0.0

# %%
#Under 20 players in Chelsea
players_under_20[players_under_20['Club'] == 'Chelsea']
# Out:
#                   Name     Club Nationality Position  Age  Matches  Starts  \
# 18  Callum Hudson-Odoi  Chelsea         ENG    FW,DF   19       23      10
# 21       Billy Gilmour  Chelsea         SCO       MF   19        5       3
#
#     Mins  Goals  Assists  Passes_Attempted  Perc_Passes_Completed  \
# 18  1059      2        3               659                   82.2
# 21   261      0        0               215                   89.3
#
#     Penalty_Goals  Penalty_Attempted    xG    xA  Yellow_Cards  Red_Cards  \
# 18              0                  0  0.12  0.26             0          0
# 21              0                  0  0.01  0.04             0          0
#
#     MinsPerMatch  GoalsPerMatch
# 18            46       0.086957
# 21            52       0.000000

# %%
#Average age of players in each group
plt.figure(figsize = (16,9))
sns.boxplot(x = 'Club', y = 'Age', data = df)
plt.xticks(rotation = 90)
plt.show()

# %%
num_players = df.groupby('Club').size()
data = (df.groupby('Club')['Age'].sum()) / num_players
data.sort_values(ascending = False)
# Out:
# Club
# Crystal Palace             28.333333
# West Ham United            27.500000
# Burnley                    27.040000
# West Bromwich Albion       26.766667
# Newcastle United           26.074074
# Manchester City            25.708333
# Tottenham Hotspur          25.625000
# Chelsea                    25.592593
# Leicester City             25.592593
# Liverpool FC               25.571429
# Everton                    25.413793
# Leeds United               25.347826
# Fulham                     25.035714
# Arsenal                    24.965517
# Sheffield United           24.814815
# Brighton                   24.555556
# Wolverhampton Wanderers    24.444444
# Aston Villa                24.291667
# Southampton                24.137931
# Manchester United          23.862069
# dtype: float64

# %%
#Total assists from each club
assist_by_club = pd.DataFrame(df.groupby('Club', as_index = False)['Assists'].sum())
sns.set_theme(style = 'whitegrid', color_codes = True)
ax = sns.barplot(x = 'Club', y = 'Assists', data = assist_by_club.sort_values(by = 'Assists'), palette = 'spring')
ax.set_xlabel('Club', fontsize = 30)
ax.set_ylabel('Assists', fontsize = 30)
plt.xticks(rotation = 75)
plt.rcParams['figure.figsize'] = (20, 10)
plt.title('Plot of Club VS Assists', fontsize = 20)
plt.show()

# %%
#Top 10 assists
top_10_assists = df[['Name', 'Club', 'Assists', 'Matches']].nlargest(n = 10, columns = 'Assists')
top_10_assists
# Out:
#                      Name               Club  Assists  Matches
# 162            Harry Kane  Tottenham Hotspur       14       35
# 34        Kevin De Bruyne    Manchester City       12       25
# 51        Bruno Fernandes  Manchester United       12       37
# 161         Son Heung-min  Tottenham Hotspur       10       37
# 273         Jack Grealish        Aston Villa       10       26
# 54        Marcus Rashford  Manchester United        9       37
# 110           Jamie Vardy     Leicester City        9       34
# 220  Raphael Dias Belloli       Leeds United        9       30
# 2             Timo Werner            Chelsea        8       35
# 136       Aaron Cresswell    West Ham United        8       36

# %%
#Goals by club
Golas_by_club = pd.DataFrame(df.groupby('Club', as_index = False)['Goals'].sum())
sns.set_theme(style = 'whitegrid', color_codes = True)
ax = sns.barplot(x = 'Club', y = 'Goals', data = Golas_by_club.sort_values(by = 'Goals'), palette = 'rocket')
ax.set_xlabel('Club', fontsize = 30)
ax.set_ylabel('Goals', fontsize = 30)
plt.xticks(rotation = 75)
plt.rcParams['figure.figsize'] = (20, 10)
plt.title('Plot of Club VS Total Goals', fontsize = 20)
plt.show()

# %%
#Most goals by players
top_10_goals = df[['Name', 'Club', 'Goals', 'Matches']].nlargest(n = 10, columns = 'Goals')
top_10_goals
# Out:
#                       Name               Club  Goals  Matches
# 162             Harry Kane  Tottenham Hotspur     23       35
# 81           Mohamed Salah       Liverpool FC     22       37
# 51         Bruno Fernandes  Manchester United     18       37
# 161          Son Heung-min  Tottenham Hotspur     17       37
# 214        Patrick Bamford       Leeds United     17       38
# 237  Dominic Calvert-Lewin            Everton     16       33
# 110            Jamie Vardy     Leicester City     15       34
# 267          Ollie Watkins        Aston Villa     14       37
# 33          İlkay Gündoğan    Manchester City     13       28
# 191    Alexandre Lacazette            Arsenal     13       31

# %%
#Goals per match
top_10_goalspermatch = df[['Name', 'GoalsPerMatch', 'Matches', 'Goals']].nlargest(n = 10, columns = 'GoalsPerMatch')
top_10_goalspermatch
# Out:
#                       Name  GoalsPerMatch  Matches  Goals
# 162             Harry Kane       0.657143       35     23
# 81           Mohamed Salah       0.594595       37     22
# 307            Joe Willock       0.571429       14      8
# 145          Jesse Lingard       0.562500       16      9
# 175            Gareth Bale       0.550000       20     11
# 74          Anthony Elanga       0.500000        2      1
# 51         Bruno Fernandes       0.486486       37     18
# 237  Dominic Calvert-Lewin       0.484848       33     16
# 120      Kelechi Iheanacho       0.480000       25     12
# 92              Diogo Jota       0.473684       19      9

# %%
#Pie chart - goals with assists and without assists
plt.figure(figsize = (16, 9))
assists = df['Assists'].sum()
data = [total_goals - assists, assists]
textprops = {"fontsize": 12}
labels = ['Goals without assists', 'Goals with assists']
colors = sns.color_palette('Set1')
plt.pie(data, labels = labels, colors = colors, autopct = '%.0f%%', textprops = textprops)
plt.show()

# %%
#Top 10 players with most yellow cards
yellow_card = df.sort_values(by = 'Yellow_Cards', ascending = False)[:10]
plt.figure(figsize = (20, 10))
plt.title('Players with most yellow cards', fontsize = 20)
yc = sns.barplot(x = yellow_card['Name'], y = yellow_card['Yellow_Cards'], label = 'Players', color = 'yellow')
plt.ylabel = ('Number of yellow cards')
yc.set_xticklabels(yc.get_xticklabels(), rotation = 45)
yc
plt.show()
